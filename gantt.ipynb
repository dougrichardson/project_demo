# %% [markdown]
# # Gantt chart

# %%
# %cd /g/data/w42/dr6273/work/project_demo/
# Out:
# /g/data/w42/dr6273/work/project_demo

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots(1, 1, figsize=(6.9, 3))

ax.barh("Fit energy models", 3, color="tab:red", hatch='//', alpha=0.7, label="WP1")
ax.barh("Produce data sets", 3, left=2, color="tab:red", hatch='//', alpha=0.7)
ax.barh("Write paper", 1, left=5, color="tab:red", hatch='//', alpha=0.7)

ax.barh("Organise forecast model data", 1, left=6, color="tab:blue", alpha=0.7, hatch='||', label="WP2")
ax.barh("Bias correction", 2.5, left=6.5, color="tab:blue", hatch='||', alpha=0.7)
ax.barh("Compute shortfall events", 2, left=9, color="tab:blue", hatch='||', alpha=0.7)
ax.barh("Analyse compound events", 4, left=11, color="tab:blue", hatch='||', alpha=0.7)
ax.barh("Write paper", 1, left=15, color="tab:blue", hatch='||', alpha=0.7)

ax.barh("Organise climate mode data", 1, left=16, color="tab:pink", hatch='++', alpha=0.7, label="WP3")
ax.barh("Analyse case studies", 8, left=17, color="tab:pink", hatch='++', alpha=0.7)
ax.barh("Composite analysis", 8, left=17, color="tab:pink", hatch='++', alpha=0.7)
ax.barh("Write paper", 1, left=25, color="tab:pink", hatch='++', alpha=0.7)

ax.barh("Build statistical forecast models", 3, left=26, color="tab:purple", hatch='..', alpha=0.7, label="WP4")
ax.barh("Compute forecast evaluation metrics", 3, left=29, color="tab:purple", hatch='..', alpha=0.7)
ax.barh("Compare forecast model skill", 3, left=32, color="tab:purple", hatch='..', alpha=0.7)
ax.barh("Write paper", 1, left=35, color="tab:purple", hatch='..', alpha=0.7)

ax.set_xlim(0, 36)
_ = ax.set_xticks(np.arange(0, 36.5, 6))
# plt.yticks(rotation=90)
ax.invert_yaxis()

# ax.axvline(12, ls="--", c="k", zorder=0)
# ax.axvline(24, ls="--", c="k", zorder=0)

ax.grid(axis="both", zorder=0)
ax.set_axisbelow(True)
ax.set_xlabel("Month")
ax.legend()

plt.savefig("./figures/gantt.pdf", format="pdf", dpi=400, bbox_inches="tight")
